# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv("C:\Temp\insurance.csv")

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# ## Data Cleaning and Exploration

# %%
df.head(5)
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.tail(5)
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
df.shape # Here 1338 are rows and 7 columns
# Out:
# (1338, 7)

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df=df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (1337, 7)

# %%
df.info
# Out:
# <bound method DataFrame.info of       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1337 rows x 7 columns]>

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
# categorical columns are 
#1 sex
# smoker
# region

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df.region.unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1337.000000  1337.000000  1337.000000   1337.000000
# mean     39.222139    30.663452     1.095737  13279.121487
# std      14.044333     6.100468     1.205571  12110.359656
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.290000     0.000000   4746.344000
# 50%      39.000000    30.400000     1.000000   9386.161300
# 75%      51.000000    34.700000     2.000000  16657.717450
# max      64.000000    53.130000     5.000000  63770.428010

# %%
print(df['age'].min())

print(df['age'].max())
# Out:
# 18
# 64

# %%
df.corr()
# Out:
#                age       sex       bmi  children    smoker    region   charges
# age       1.000000  0.019814  0.109344  0.041536  0.025587  0.006691  0.298308
# sex       0.019814  1.000000 -0.046397 -0.017848  0.076596  0.017150 -0.058044
# bmi       0.109344 -0.046397  1.000000  0.012755 -0.003746 -0.261999  0.198401
# children  0.041536 -0.017848  0.012755  1.000000 -0.007331  0.020206  0.067389
# smoker    0.025587  0.076596 -0.003746 -0.007331  1.000000  0.053454 -0.787234
# region    0.006691  0.017150 -0.261999  0.020206  0.053454  1.000000 -0.056070
# charges   0.298308 -0.058044  0.198401  0.067389 -0.787234 -0.056070  1.000000

# %% [markdown]
# ## Data Visualisation

# %%
#Distribution of Age Value
sns.set();
plt.figure(figsize=(6,6));
sns.distplot(df['age']);
plt.title('Age Distribution');
plt.show();
# Out:
# C:\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#Gender Column
plt.figure(figsize=(6,6))
sns.countplot(x='sex',data=df);
plt.title('Sex Distribution');
plt.show();

# %%
df['sex'].value_counts()
# Out:
# male      675
# female    662
# Name: sex, dtype: int64

# %%
#Bmi Distribution
sns.set()
plt.figure(figsize=(6,6))
sns.distplot(df['bmi'])
plt.title('Bmi Distribution')
plt.show()
# Out:
# C:\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Normal Bmi Range = 18.5 to 24.9

# %%
#Children Column
plt.figure(figsize=(6,6))
sns.countplot(x='children',data=df)
plt.title('children')
plt.show()

# %%
df['children'].value_counts()
# Out:
# 0    573
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: children, dtype: int64

# %%
#Smoker Column
plt.figure(figsize=(6,6))
sns.countplot(x='smoker',data=df)
plt.title('Smoker')
plt.show()

# %%
df['smoker'].value_counts()
# Out:
# no     1063
# yes     274
# Name: smoker, dtype: int64

# %%
#region Column
plt.figure(figsize=(6,6))
sns.countplot(x='region',data=df)
plt.title('Region')
plt.show()

# %%
df['region'].value_counts()
# Out:
# southeast    364
# southwest    325
# northeast    324
# northwest    324
# Name: region, dtype: int64

# %%
#Distribution of charges value
sns.set()
plt.figure(figsize=(6,6))
sns.distplot(df['charges'])
plt.title('Charge Distribution')
plt.show()
# Out:
# C:\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Encoding the categorical column

# %%
#Encoding Sex column
df.replace({'sex':{'male':0,'female':1}},inplace=True)

#encoding Smoker column
df.replace({'smoker':{'yes':0, 'no':1}} ,inplace=True)

#Encoding region  column
df.replace({'region':{'southeast':0, 'southwest':1, 'northeast':2, 'northwest':3}},inplace=True)
# Out:
# C:\anaconda3\lib\site-packages\pandas\core\indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)

# %%
df.copy
# Out:
# <bound method NDFrame.copy of       age  sex     bmi  children  smoker  region      charges
# 0      19    1  27.900         0       0       1  16884.92400
# 1      18    0  33.770         1       1       0   1725.55230
# 2      28    0  33.000         3       1       0   4449.46200
# 3      33    0  22.705         0       1       3  21984.47061
# 4      32    0  28.880         0       1       3   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    0  30.970         3       1       3  10600.54830
# 1334   18    1  31.920         0       1       2   2205.98080
# 1335   18    1  36.850         0       1       0   1629.83350
# 1336   21    1  25.800         0       1       1   2007.94500
# 1337   61    1  29.070         0       0       3  29141.36030
#
# [1337 rows x 7 columns]>

# %% [markdown]
# ### splitting the features and targets

# %%
f=df.drop(columns='charges', axis=1)
t=df['charges']

# %%
f
# Out:
#       age  sex     bmi  children  smoker  region
# 0      19    1  27.900         0       0       1
# 1      18    0  33.770         1       1       0
# 2      28    0  33.000         3       1       0
# 3      33    0  22.705         0       1       3
# 4      32    0  28.880         0       1       3
# ...   ...  ...     ...       ...     ...     ...
# 1333   50    0  30.970         3       1       3
# 1334   18    1  31.920         0       1       2
# 1335   18    1  36.850         0       1       0
# 1336   21    1  25.800         0       1       1
# 1337   61    1  29.070         0       0       3
#
# [1337 rows x 6 columns]

# %%
t
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1337, dtype: float64

# %%
# Smoker and Age
plt.figure(figsize=(30,6));
plt.xticks(fontsize=20);
plt.yticks(fontsize=20);
plt.xlabel('x-axis',fontsize=25);
plt.ylabel('y-axis',fontsize=25);
sns.barplot(x='age',y='smoker',data=df);

# %%
## BMI and Age 
plt.figure(figsize=(30,6));
plt.xticks(fontsize=20);
plt.yticks(fontsize=20);
plt.xlabel('x-axis',fontsize=25);
plt.ylabel('y-axis',fontsize=25);
sns.barplot(x='age',y='bmi',data=df);

# %%
#Relation between Region and Smoker count
plt.figure(figsize=(30,6));
plt.xticks(fontsize=20);
plt.yticks(fontsize=20);
plt.xlabel('x-axis',fontsize=25);
plt.ylabel('y-axis',fontsize=25);
sns.barplot(x='region',y='smoker',data=df);

# %% [markdown]
# #### Here we can see region 1 and region 3 i,e southwest and northeast  have highest smoker count

# %%
#Region wise smoker count
df.groupby(["region", "smoker"]).size()
# Out:
# region  smoker
# 0       0          91
#         1         273
# 1       0          58
#         1         267
# 2       0          67
#         1         257
# 3       0          58
#         1         266
# dtype: int64

# %% [markdown]
# ##### Here 0=southeast, 1=southwest, 3=northeast, 4=northwest  And in smoker 0 means yes whereas 1 means no

# %%
# Male and Female smoker count
df.groupby(["sex", "smoker"]).size().reset_index(name="time")
# Out:
#    sex  smoker  time
# 0    0       0   159
# 1    0       1   516
# 2    1       0   115
# 3    1       1   547

# %%
# Relationship Between charges and age
plt.figure(figsize=(30,6));
plt.xticks(fontsize=20);
plt.yticks(fontsize=20);
plt.xlabel('x-axis',fontsize=25);
plt.ylabel('y-axis',fontsize=25);
sns.barplot(x='age',y='charges',data=df);

# %%
# charges on the bases on sex
plt.figure(figsize=(30,6));
plt.xticks(fontsize=20);
plt.yticks(fontsize=20);
plt.xlabel('x-axis',fontsize=25);
plt.ylabel('y-axis',fontsize=25);
sns.barplot(x='sex',y='charges',data=df);

# %%
# Relationship Between Charges and Region
plt.figure(figsize=(30,6));
plt.xticks(fontsize=20);
plt.yticks(fontsize=20);
plt.xlabel('x-axis',fontsize=25);
plt.ylabel('y-axis',fontsize=25);
sns.barplot(x='region',y='charges',data=df);

# %% [markdown]
# ##### Charges are highest in southeast region
