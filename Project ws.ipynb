# %%
#importing the Libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd
import csv

# %% [markdown]
# ### WEB SCRAPPING

# %%
url="https://www.flipkart.com/search?q=laptop&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=off&as=off"

# %%
res=requests.get(url=url)

# %%
res
# Out:
# <Response [200]>

# %%
res.content #HTML content
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app_modules.chunk.94b5e7.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.dd97f3.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/a
# ...

# %%
soup=BeautifulSoup(res.content,"html.parser")
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n <head>\n  <link href="https://rukminim1.flixcart.com" rel="preconnect"/>\n  <link href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app_modules.chunk.94b5e7.css" rel="stylesheet"/>\n  <link href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.dd97f3.css" rel="stylesheet"/>\n  <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>\n  <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>\n  <meta content="102988293558" property="fb:page_id"/>\n  <meta content="658873552,624500995,100000233612389" property="fb:admins"/>\n  <meta content="noodp" name="robots"/>\n  <link href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/>\n  <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>\n  <meta content="website" property="og:type"/>\n  <meta content="Flipkart.com" name="og_site_name" property="og:site_name"/
# ...

# %%
products=[]
prices=[]
ratings=[]
product=soup.find('div',attrs={'class':'_4rR01T'})
print(product.text)
# Out:
# DELL Inspiron Core i3 11th Gen - (8 GB/1 TB HDD/256 GB SSD/Windows 11 Home) Inspiron 3511 Thin and Lig...

# %%
for a in soup.findAll('a',href=True,attrs={'class':'_1fQZEK'}):
    name=a.find('div',attrs={'class':'_4rR01T'})
    price=a.find('div',attrs={'class':'_30jeq3 _1_WHN1'})
    rating=a.find('div',attrs={'class':'_3LWZlK'})
    products.append(name.text)
    prices.append(price.text)
    ratings.append(rating.text)

# %%
df=pd.DataFrame({"Producuct Name":products,"Prices":prices,"Ratings":ratings})
df.head()
# Out:
#                                       Producuct Name   Prices Ratings
# 0  DELL Inspiron Core i3 11th Gen - (8 GB/1 TB HD...  ₹42,490     4.6
# 1  acer Aspire 7 Core i5 10th Gen - (8 GB/512 GB ...  ₹49,990     4.4
# 2  ASUS VivoBook 15 (2021) Core i3 10th Gen - (8 ...  ₹37,990     4.4
# 3  ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/5...  ₹56,990     4.5
# 4  Lenovo IdeaPad 3 Core i3 10th Gen - (8 GB/256 ...  ₹37,490     4.3

# %%
df
# Out:
#                                        Producuct Name   Prices Ratings
# 0   DELL Inspiron Core i3 11th Gen - (8 GB/1 TB HD...  ₹42,490     4.6
# 1   acer Aspire 7 Core i5 10th Gen - (8 GB/512 GB ...  ₹49,990     4.4
# 2   ASUS VivoBook 15 (2021) Core i3 10th Gen - (8 ...  ₹37,990     4.4
# 3   ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/5...  ₹56,990     4.5
# 4   Lenovo IdeaPad 3 Core i3 10th Gen - (8 GB/256 ...  ₹37,490     4.3
# 5   Lenovo IdeaPad 3 Core i3 11th Gen - (8 GB/512 ...  ₹40,490       4
# 6   APPLE MacBook Air M1 - (8 GB/256 GB SSD/Mac OS...  ₹83,990     4.7
# 7   ASUS Vivobook Pro 14 OLED (2021) Core i5 11th ...  ₹69,990     4.5
# 8   acer Aspire 7 Ryzen 5 Hexa Core 5500U - (8 GB/...  ₹52,990     4.5
# 9   HP Ryzen 3 Dual Core 3250U - (8 GB/256 GB SSD/...  ₹38,490     4.3
# 10  DELL Inspiron Core i3 11th Gen - (8 GB/256 GB ...  ₹41,490     4.8
# 11  ASUS VivoBook 15 (2021) Core i3 11th Gen - (4 ...  ₹34,990     4.3
# ...

# %%
df.tail()
# Out:
#                                        Producuct Name   Prices Ratings
# 19  DELL Vostro Core i3 11th Gen - (8 GB/256 GB SS...  ₹40,490     4.3
# 20  DELL Vostro Core i3 11th Gen - (8 GB/1 TB HDD/...  ₹37,990       4
# 21  HP Core i5 11th Gen - (8 GB/512 GB SSD/Windows...  ₹56,990     2.6
# 22  HP Core i3 11th Gen - (8 GB/512 GB SSD/Windows...  ₹41,990     4.3
# 23  HP Core i3 10th Gen - (8 GB/512 GB SSD/Windows...  ₹40,990     4.3

# %%
df.columns
# Out:
# Index(['Producuct Name', 'Prices', 'Ratings'], dtype='object')
